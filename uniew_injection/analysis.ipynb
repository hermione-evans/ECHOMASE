# %% [markdown]
# # logB distribution
# Fig 3

# %%
import pandas as pd
import scipy
import os
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats
import bilby
import corner

from glob import glob

# %%
file_array = glob('npoints=1000_duration=52_4parameter_HWP/*0.077*.csv')
file_array.sort()
plt.figure(figsize=(8, 5))
file = file_array[0]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-7, log_b.max() + 5, 200)
plt.plot(x, probDensityFun(x), color='C0')
plt.axvline(np.mean(log_b), color='C0', linestyle=":")
plt.hist(log_b,14,density=1,alpha=0.5,label='new',color='C0',)
file = file_array[1]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-5, log_b.max() + 1, 200)
#plt.plot(x, probDensityFun(x), color='C1')
plt.axvline(np.mean(log_b), color='C1', linestyle=":")
plt.hist(log_b,3,density=1,alpha=0.5,label='old',color='C1',)
# ax = plt.gca()
# plt.text(0.47,0.9, r'$T/\tau=13,N=49$', horizontalalignment='center',verticalalignment='center',transform=ax.transAxes,fontsize= 14)
# plt.text(0.05,0.9, '(a)', horizontalalignment='center',verticalalignment='center',transform=ax.transAxes,fontsize= 14)
plt.text(23,0.045,'$T/τ_{inj}=13$, $N=49$',fontsize=16)
plt.text(-13,0.046,'(a)',fontsize=16)
plt.legend()
plt.tick_params(labelsize =14)
plt.xlabel("log Bayes factor",fontsize=15)
plt.ylim(0,0.051)
plt.xlim(-16,105)
plt.savefig("logB_HFN49_signal.pdf",dpi=300)
# Out:
# (-16.0, 105.0)

# %%
file_array = glob('npoints=1000_duration=1_4parameter_HWP/*0.077*.csv')
file_array.sort()
plt.figure(figsize=(8, 5))
file = file_array[0]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-8, log_b.max()+3 , 200)
plt.plot(x, probDensityFun(x), color='C0')
plt.axvline(np.mean(log_b), color='C0', linestyle=":")
plt.hist(log_b,12,density=1,alpha=0.5,label='new',color='C0',)
file = file_array[1]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-8, log_b.max()+3 , 200)
plt.plot(x, probDensityFun(x), color='C1')
plt.axvline(np.mean(log_b), color='C1', linestyle=":")
plt.hist(log_b,12,density=1,alpha=0.5,label='old',color='C1',)
# ax = plt.gca()
# plt.text(0.6,0.9, r'$T/\tau=1/4,N=49$', horizontalalignment='center',verticalalignment='center',transform=ax.transAxes,fontsize= 14)
# plt.text(0.05,0.9, '(a)', horizontalalignment='center',verticalalignment='center',transform=ax.transAxes,fontsize= 14)
plt.text(8,0.09,'$T/τ_{inj}=1/4$, $N=49$',fontsize=16)
plt.text(-8,0.093,'(b)',fontsize=16)

plt.legend()
plt.tick_params(labelsize =14)
plt.xlabel("log Bayes factor",fontsize=15)
plt.xlim(-9,30)
plt.savefig("logB_LFN49_signal.pdf",dpi=300)
# Out:
# (-9.0, 30.0)

# %%
file_array = glob('npoints=1000_duration=52_n10_4parameter_HWP/*0.140*.csv')
file_array.sort()
plt.figure(figsize=(8, 5))
file = file_array[0]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-3.5, log_b.max()+10 , 200)
plt.plot(x, probDensityFun(x), color='C0')
plt.axvline(np.mean(log_b), color='C0', linestyle=":")
plt.hist(log_b,11,density=1,alpha=0.5,label='new',color='C0',)
file = file_array[1]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-8, log_b.max()+3 , 200)
plt.plot(x, probDensityFun(x), color='C1')
plt.axvline(np.mean(log_b), color='C1', linestyle=":")
plt.hist(log_b,7,density=1,alpha=0.5,label='old',color='C1',)
# ax = plt.gca()
# plt.text(0.6,0.9, r'$T/\tau=1/4,N=49$', horizontalalignment='center',verticalalignment='center',transform=ax.transAxes,fontsize= 14)
# plt.text(0.05,0.9, '(a)', horizontalalignment='center',verticalalignment='center',transform=ax.transAxes,fontsize= 14)
plt.text(35,0.045,'$T/τ_{inj}=13$, $N=10$',fontsize=16)
plt.text(-12,0.046,'(c)',fontsize=16)

plt.legend()
plt.tick_params(labelsize =14)
plt.xlabel("log Bayes factor",fontsize=15)
plt.xlim(-16,105)
plt.savefig("logB_HFN10_signal.pdf",dpi=300)
# Out:
# (-16.0, 105.0)

# %%
file_array = glob('npoints=1000_duration=1_n10_4parameter_HWP/*0.140*.csv')
file_array.sort()
plt.figure(figsize=(8, 5))
file = file_array[0]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-4, log_b.max() + 10, 200)
plt.plot(x, probDensityFun(x), color='C0')
plt.axvline(np.mean(log_b), color='C0', linestyle=":")
plt.hist(log_b,11,density=1,alpha=0.5,label='new',color='C0',)
file = file_array[1]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-4, log_b.max() + 3, 200)
plt.plot(x, probDensityFun(x), color='C1')
plt.axvline(np.mean(log_b), color='C1', linestyle=":")
plt.hist(log_b,11,density=1,alpha=0.5,label='old',color='C1',)
# ax = plt.gca()
# plt.text(0.6,0.9, r'$T/\tau=1/4,N=49$', horizontalalignment='center',verticalalignment='center',transform=ax.transAxes,fontsize= 14)
# plt.text(0.05,0.9, '(a)', horizontalalignment='center',verticalalignment='center',transform=ax.transAxes,fontsize= 14)
plt.text(16,0.065,'$T/τ_{inj}=1/4$, $N=10$',fontsize=16)
plt.text(-4.5,0.066,'(d)',fontsize=16)

plt.legend()
plt.tick_params(labelsize =14)
plt.xlabel("log Bayes factor",fontsize=15)
plt.xlim(-6,45)
plt.savefig("logB_LFN10_signal.pdf",dpi=300)
# Out:
# (-6.0, 45.0)

# %% [markdown]
# # Corner Plots
# Fig 4

# %%
import pandas as pd
import scipy
import os
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats
import bilby
import corner

from glob import glob

# %%
result_json_index_high_new = glob('npoints=1000_duration=52_4parameter_HWP/newlikelihood/*0.077*_SNR*.json')
result_json_index_high_new.sort()
posterior_array_high_new = [bilby.result.read_in_result(result_single).posterior for result_single in result_json_index_high_new]
posterior_all_plus_high_new = pd.concat(posterior_array_high_new,ignore_index=True)
result_json_index_high_old = glob('npoints=1000_duration=52_4parameter_HWP/oldlikelihood/*0.077*_SNR*.json')
result_json_index_high_old.sort()
posterior_array_high_old = [bilby.result.read_in_result(result_single).posterior for result_single in result_json_index_high_old]
posterior_all_plus_high_old = pd.concat(posterior_array_high_old,ignore_index=True)
print(len(result_json_index_high_new),len(result_json_index_high_old))
# Out:
# 100 100

# %%
result_json_index_low_new = glob('npoints=1000_duration=1_4parameter_HWP/newlikelihood/*0.077*SNR*.json')
result_json_index_low_new.sort()

posterior_array_low_new = [bilby.result.read_in_result(result_single).posterior for result_single in result_json_index_low_new]
posterior_all_plus_low_new = pd.concat(posterior_array_low_new,ignore_index=True)

result_json_index_low_old = glob('npoints=1000_duration=1_4parameter_HWP/oldlikelihood/*0.077*SNR*.json')
result_json_index_low_old.sort()
len(result_json_index_low_old)
posterior_array_low_old = [bilby.result.read_in_result(result_single).posterior for result_single in result_json_index_low_old]
posterior_all_plus_low_old = pd.concat(posterior_array_low_old,ignore_index=True)
print(len(result_json_index_low_new),len(result_json_index_low_old))
# Out:
# 100 100

# %%
result_json_index_high_new_n10 = glob('npoints=1000_duration=52_n10_4parameter_HWP/newlikelihood/*0.140*.json')
result_json_index_high_new_n10.sort()
len(result_json_index_high_new_n10)
posterior_array_high_new_n10 = [bilby.result.read_in_result(result_single).posterior for result_single in result_json_index_high_new_n10]
posterior_all_plus_high_new_n10 = pd.concat(posterior_array_high_new_n10,ignore_index=True)

result_json_index_high_old_n10 = glob('npoints=1000_duration=52_n10_4parameter_HWP/oldlikelihood/*0.140*.json')
result_json_index_high_old_n10.sort()
len(result_json_index_high_old_n10)
posterior_array_high_old_n10 = [bilby.result.read_in_result(result_single).posterior for result_single in result_json_index_high_old_n10]
posterior_all_plus_high_old_n10 = pd.concat(posterior_array_high_old_n10,ignore_index=True)
print(len(result_json_index_high_new_n10),len(result_json_index_high_old_n10))
# Out:
# 100 100

# %%
result_json_index_low_new_n10 = glob('npoints=1000_duration=1_n10_4parameter_HWP/newlikelihood/*0.140*.json')
result_json_index_low_new_n10.sort()
len(result_json_index_low_new_n10)
posterior_array_low_new_n10 = [bilby.result.read_in_result(result_single).posterior for result_single in result_json_index_low_new_n10]
posterior_all_plus_low_new_n10 = pd.concat(posterior_array_low_new_n10,ignore_index=True)

result_json_index_low_old_n10 = glob('npoints=1000_duration=1_n10_4parameter_HWP/oldlikelihood/*0.140*.json')
result_json_index_low_old_n10.sort()
len(result_json_index_low_old_n10)
posterior_array_low_old_n10 = [bilby.result.read_in_result(result_single).posterior for result_single in result_json_index_low_old_n10]
posterior_all_plus_low_old_n10 = pd.concat(posterior_array_low_old,ignore_index=True)
print(len(result_json_index_low_new_n10),len(result_json_index_low_old_n10))
# Out:
# 100 100

# %%
import matplotlib.lines as mlines
range_array = [[5.824, 5.834], [5.81, 5.85], [5.81, 5.85], [5.73, 5.93]]
name_array = ['n49_high_res', 'n49_low_res', 'n10_high_res', 'n10_low_res']
name_string_array = [r'(a) $T/\tau_{inj}=13,N=49$', r'(b) $T/\tau_{inj}=1/4,N=49$', r'(c) $T/\tau_{inj}=13,N=10$', r'(d) $T/\tau_{inj}=1/4,N=10$']
for posteriornew, posteriorold, result_files, plotrange, names,name_string in zip([posterior_all_plus_high_new, posterior_all_plus_low_new, posterior_all_plus_high_new_n10, posterior_all_plus_low_new_n10], [posterior_all_plus_high_old, posterior_all_plus_low_old, posterior_all_plus_high_old_n10, posterior_all_plus_low_old_n10], [result_json_index_high_new, result_json_index_low_new, result_json_index_high_new_n10, result_json_index_low_new_n10], range_array, name_array,name_string_array):
    line1 = mlines.Line2D([], [], color='C0', label='new')
    line2 = mlines.Line2D([], [], color='C1', label='old')
    line3 = mlines.Line2D([], [], color='gray', label='injected value')
    line4 = mlines.Line2D([], [], ls='--', color='black',
                          alpha=0.5, label='prior')

    result = bilby.result.read_in_result(result_files[0])
    priors = result.priors

    spacing_injected = 5.83
    width_injected = 0.25

    datanew = np.transpose([posteriornew.spacing.values/spacing_injected,
                           np.log10(posteriornew.width.values/width_injected)])
    dataold = np.transpose([posteriorold.spacing.values/spacing_injected,
                           np.log10(posteriorold.width.values/width_injected)])
    
    range_spacing = np.array(plotrange)/spacing_injected
    range_width = [np.log10(priors['width'].minimum/width_injected),
                   np.log10(priors['width'].maximum/width_injected)]
    kwargsnew = dict(labels=[r"$\Delta f/ \Delta f_{inj}$", r"$\log_{10}{\tau_{inj}/\tau}$"], range=[range_spacing, range_width], show_titles=False, levels=(1 - np.exp(-0.5), 1 - np.exp(-2)), hist_kwargs=dict(
        density=True), contour_kwargs=dict(alpha=0.5), hist2d_kwargs=dict(plot_density=True), label_kwargs=dict(fontsize=16), color='C0', fill_contours=False, plot_contours=True, bins=50)
    kwargsold = dict(labels=[r"$\Delta f/ \Delta f_{inj}$", r"$\log_{10}{\tau_{inj}/\tau}$"], range=[range_spacing, range_width], show_titles=False, levels=(1 - np.exp(-0.5), 1 - np.exp(-2)), hist_kwargs=dict(
        density=True), contour_kwargs=dict(alpha=0.5), hist2d_kwargs=dict(plot_density=True), label_kwargs=dict(fontsize=16), color='C1', fill_contours=False, plot_contours=True, bins=50)

    def get_normalisation_weight(len_current_samples, len_of_longest_samples):
        return np.ones(len_current_samples) * (len_of_longest_samples / len_current_samples)
    figure = corner.corner(datanew, **kwargsnew)
    corner.corner(dataold, **kwargsold, fig=figure)

    inject = np.array([1, 0])
    corner.overplot_lines(figure, inject, color="gray")
    corner.overplot_points(figure, inject[None], marker="s", color="gray")

    axes = np.array(figure.axes).reshape((2, 2))
    # ax = axes[1,1]
    # logprior = 1/(np.log10(priors['width'].maximum/priors['width'].minimum))
    # ax.plot(np.log10(np.linspace(priors['width'].minimum, priors['width'].maximum, 1000)),np.linspace(logprior,logprior, 1000),color = 'black',ls='--',alpha = 0.5,label = 'prior')
    ax = axes[1, 0]

    ax.hist2d(posteriornew.spacing.values/spacing_injected, np.log10(posteriornew.width.values /
              width_injected), bins=50, density=True, cmap='Blues', range=[range_spacing, range_width])
    ax.hist2d(posteriorold.spacing.values/spacing_injected, np.log10(posteriorold.width.values/width_injected),
              bins=50, density=True, cmap='Oranges', alpha=0.5, range=[range_spacing, range_width])

    ax.ticklabel_format(axis="x", style="sci",
                        scilimits=(0, 0), useMathText=True)
    ax = axes[0,1]
    ax.text(0.5, 0.3, name_string, horizontalalignment='center',verticalalignment='center', transform=ax.transAxes, fontsize= 12)
    
    ax = axes[1, 1]
    ticks_array = ax.get_xticks()[0:-1:]
    ticks_label_array = ax.get_xticklabels()[0:-1:]

    plt.legend(handles=[line1, line2, line3],
               bbox_to_anchor=(0., 2.0, 1., .0), loc=0)
    plt.savefig(names+".pdf", dpi=300)
    plt.show()
    plt.close()

    kwargsnew = dict(show_titles=False, levels=(1 - np.exp(-0.5), 1 - np.exp(-2)), hist_kwargs=dict(density=True), hist2d_kwargs=dict(plot_density=True), contour_kwargs=dict(
        alpha=0.5), label_kwargs=dict(fontsize=16), color='C0', quantiles=[0.05, 0.95], plot_datapoints=False, fill_contours=False, plot_contours=True, bins=50)
    kwargsold = dict(show_titles=False, levels=(1 - np.exp(-0.5), 1 - np.exp(-2)), hist_kwargs=dict(density=True), hist2d_kwargs=dict(plot_density=True), contour_kwargs=dict(
        alpha=0.5), label_kwargs=dict(fontsize=16), color='C1', quantiles=[0.05, 0.95], plot_datapoints=False, fill_contours=False, plot_contours=True, bins=50)

    kwargsnew['labels'] = [r"$\Delta f$",
                           r"$q_0$", r"$A$", r"$\log_{10}{1/\tau}$"]
    kwargsold['labels'] = [r"$\Delta f$",
                           r"$q_0$", r"$A$", r"$\log_{10}{1/\tau}$"]

    kwargsnew['range'] = [[priors['spacing'].minimum, priors['spacing'].maximum], [priors['phase'].minimum, priors['phase'].maximum], [
        priors['amplitude'].minimum, priors['amplitude'].maximum], [np.log10(priors['width'].minimum), np.log10(priors['width'].maximum)]]
    kwargsold['range'] = [[priors['spacing'].minimum, priors['spacing'].maximum], [priors['phase'].minimum, priors['phase'].maximum], [
        priors['amplitude'].minimum, priors['amplitude'].maximum], [np.log10(priors['width'].minimum), np.log10(priors['width'].maximum)]]

    datanew = np.transpose([posteriornew.spacing.values, posteriornew.phase.values,
                           posteriornew.amplitude.values, np.log10(posteriornew.width.values)])
    dataold = np.transpose([posteriorold.spacing.values, posteriorold.phase.values,
                           posteriorold.amplitude.values, np.log10(posteriorold.width.values)])

    figure = corner.corner(datanew, **kwargsnew)
    corner.corner(dataold, **kwargsold, fig=figure)
    plt.savefig(names+"_Full_corner.pdf", dpi=300)
    plt.show()
    plt.close()
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# # violin plots
# Fig 5

# %% [markdown]
# ## SNR trend

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d
import bilby

from bilby.core.prior import PriorDict
import csv
import os


import sys
sys.path.append("..")
from comb_models_version2 import qnmcombmodel_cut as combmodel

noise0 = np.load('../echo_wave_injection/noise100_500second.npy')

# %%
phase_injected = 1.26
spacing_injected = 5.83
snr_array = []
qfactor_array = []
for duration in [1,2,3,4,8,12,24,52]:
    samplingrate = 4096 
    dt = 1/samplingrate # time resolution in unit of second
    df = 1/duration
    length = int(duration/dt)
    length0 = int(500/dt)

    #     noise = np.random.normal(0, 1,100*length0)
    #     np.save('noise100_500second',noise)
    # These 2 lines aim to generate noise
    


    NFFT = int(0.5 / dt) # the segment length is 0.5s
    fs = int(1/ dt)
    psd_window = np.blackman(NFFT)
    NOVL = int(NFFT/2)

    fmin = 50
    fmax = 339


    inject_params=dict()
    inject_params['width']=1/4

    inject_params['phase'] = phase_injected
    inject_params['spacing'] = spacing_injected
    #inject_params['fmin'] = fmin
    #inject_params['fmax'] = fmax
    inject_params['duration'] = duration
    
    
    echoamplitude = 0.077
    
    amplitude_injected = echoamplitude
    inject_params['amplitude'] = amplitude_injected
    
    i = 0
    
    noisep = noise0[i*length0:(i+1)*length0]
    noise = noisep[0:length]

    Pxx_strain, freqs = mlab.psd(noisep, Fs = fs, NFFT = NFFT,window = psd_window,noverlap = NOVL)
    psd_strain = interp1d(freqs, Pxx_strain)
    
    frequency = np.arange(0,int(freqs.max()),df)

    
    noisefre = dt * np.fft.fft(noise)[0:len(frequency)]
    strainfre = noisefre + combmodel(frequency,**inject_params)[0] * np.exp(1j*combmodel(frequency,**inject_params)[1])
    
    frequencye = frequency[int(fmin/df):int(fmax/df+2)]
    
    hi = combmodel(frequencye,**inject_params)[0] * np.exp(1j*combmodel(frequencye,**inject_params)[1])
    
    rho_opt_signal = np.sqrt(4*df * np.sum(np.abs(hi)**2/psd_strain(frequencye)))
    snr_array.append(rho_opt_signal)
    qfactor_array.append(np.min([duration,4])*spacing_injected)
    print(duration,snr_array[-1],qfactor_array[-1])
# Out:
# 1 10.737694180781324 5.83
# 2 13.608093858841755 11.66
# 3 15.05152387444897 17.490000000000002
# 4 15.752329148316147 23.32
# 8 16.498957490757075 23.32
# 12 16.34300146346134 23.32
# 24 16.113239267256002 23.32
# 52 16.120142485481203 23.32

# %% [markdown]
# ## violin plot for SNR and $\tau \Delta f$

# %%
file_array_new_2 = []
file_array_old_2 = []
for time_duration in [1,2,3,4,8,12,24,52]:
    result_json_new=glob('*duration=%d_*HWP/newlikelihood/*0.077*SNR_*.json'%time_duration)
    result_json_new.sort()
    file_array_new_2.append(result_json_new)
    result_json_old=glob('*duration=%d_*HWP/oldlikelihood/*0.077*SNR_*.json'%time_duration)
    result_json_old.sort()
    file_array_old_2.append(result_json_old)
# result_json_new = glob('*version3/*duration=52_*HWP/newlikelihood/*0.077*SNR_*.json')
# result_json_new.sort()
# file_array_new_2.append(result_json_new)
# result_json_old = glob('*version3/*duration=52_*HWP/oldlikelihood/*0.077*SNR_*.json')
# result_json_old.sort()
# file_array_old_2.append(result_json_old)

# %%
new_likelihood_SNR = []
old_likelihood_SNR = []
new_likelihood_qfactor = []
old_likelihood_qfactor = []
for file_array_new_3,file_array_old_3 in zip(file_array_new_2,file_array_old_2):
    posterior_array_new = [bilby.result.read_in_result(result_single).posterior for result_single in file_array_new_3]
    posterior_array_old = [bilby.result.read_in_result(result_single).posterior for result_single in file_array_old_3]
    posterior_array_allplus_new = pd.concat(posterior_array_new,ignore_index=True)
    posterior_array_allplus_old = pd.concat(posterior_array_old,ignore_index=True)
    new_likelihood_SNR.append(posterior_array_allplus_new['SNR'])
    old_likelihood_SNR.append(posterior_array_allplus_old['SNR'])
    new_likelihood_qfactor.append(posterior_array_allplus_new['spacing']/posterior_array_allplus_new['width'])
    old_likelihood_qfactor.append(posterior_array_allplus_old['spacing']/posterior_array_allplus_old['width'])

# %%
import matplotlib.lines as mlines
import matplotlib.patches as mpatches

duration_array = [1,2,3,4,8,12,24,52]

# quantiles8 = [[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95]]
# quantiles7 = [[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95]]

fig, ax = plt.subplots(figsize = (15,5),constrained_layout=True)
labels = []
parts1 = ax.violinplot(new_likelihood_SNR,positions=np.log(duration_array),showmedians=False,widths = 0.25,showextrema=False)
parts2 = ax.violinplot(old_likelihood_SNR,positions=np.log(duration_array),showmedians=False,widths = 0.25,showextrema=False)

ax.set_xticks(np.log(duration_array))
ax.set_xticklabels([str(x) for x in duration_array],fontsize = 12)

quantile_values = [5, 95]
positions = np.log(duration_array)
for i, pos in enumerate(positions):
    lower1, upper1 = np.percentile(new_likelihood_SNR[i], quantile_values)
    lower2, upper2 = np.percentile(old_likelihood_SNR[i], quantile_values)
    ax.hlines([lower1, upper1], pos-0.25/2, pos, color='C0', lw=2)
    ax.hlines([lower2, upper2], pos, pos+0.25/2, color='C1', lw=2)
for pc in parts1['bodies']:
    for path in pc.get_paths():
        vertices = path.vertices
        vertices[:, 0] = np.clip(vertices[:, 0], -np.inf, vertices[:, 0].mean())
for pc in parts2['bodies']:
    for path in pc.get_paths():
        vertices = path.vertices
        vertices[:, 0] = np.clip(vertices[:, 0], vertices[:, 0].mean(),np.inf)
        
patch1 = mpatches.Patch(color=parts1["bodies"][0].get_facecolor().flatten(), label='new')
patch2 = mpatches.Patch(color=parts2["bodies"][0].get_facecolor().flatten(), label='old')

line1 = mlines.Line2D([], [], color='grey', label='90% credible interval')
points1 = mlines.Line2D([], [], color='grey', marker='o',linestyle='None', label='median')

line3 = mlines.Line2D([], [], color='green',ls='--', label='SNR theory trend')

positions = np.log(duration_array)
medians1 = [np.median(x) for x in new_likelihood_SNR]

ax.scatter(positions, medians1, marker='o', color=parts1["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)

medians2 = [np.median(x) for x in old_likelihood_SNR]
ax.scatter(positions, medians2, marker='o', color=parts2["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)
ax.plot(positions,snr_array,color = 'green',ls = '--',label = 'SNR theory trend')
ax.set_xticks(np.log(duration_array))
ax.set_xticklabels([str(x/4) for x in duration_array],fontsize = 12)
ax.set_xlabel(r'$T/\tau$',fontsize = 18)
ax.set_ylabel('SNR',fontsize = 18)
ax.set_ylim(0, 25)

plt.yticks(fontsize = 12)
plt.legend(handles=[patch1, patch2, line1, points1,line3], loc=2,fontsize = 11)
plt.savefig('SNR_violin_plot_divided.pdf',dpi=300)
plt.show()
plt.close()


log10_new_likelihood_qfactor = []
log10_old_likelihood_qfactor = []
for i in range(len(new_likelihood_qfactor)):
    log10_new_likelihood_qfactor.append(np.log10(new_likelihood_qfactor[i]))
    log10_old_likelihood_qfactor.append(np.log10(old_likelihood_qfactor[i]))

fig, ax = plt.subplots(figsize = (15,5),constrained_layout=True)
labels = []

parts1 = ax.violinplot(log10_new_likelihood_qfactor,positions=np.log(duration_array),showmedians=False,widths = 0.25,showextrema=False)
parts2 = ax.violinplot(log10_old_likelihood_qfactor,positions=np.log(duration_array),showmedians=False,widths = 0.25,showextrema=False)
for i, pos in enumerate(positions):
    lower1, upper1 = np.percentile(log10_new_likelihood_qfactor[i], quantile_values)
    lower2, upper2 = np.percentile(log10_old_likelihood_qfactor[i], quantile_values)
    ax.hlines([lower1, upper1], pos-0.25/2, pos, color='C0', lw=2)
    ax.hlines([lower2, upper2], pos, pos+0.25/2, color='C1', lw=2)
for pc in parts1['bodies']:
    for path in pc.get_paths():
        vertices = path.vertices
        vertices[:, 0] = np.clip(vertices[:, 0], -np.inf, vertices[:, 0].mean())
for pc in parts2['bodies']:
    for path in pc.get_paths():
        vertices = path.vertices
        vertices[:, 0] = np.clip(vertices[:, 0], vertices[:, 0].mean(),np.inf)
        
    
ax.set_xticks(np.log(duration_array))
ax.set_xticklabels([str(x) for x in duration_array],fontsize = 12)

patch1 = mpatches.Patch(color=parts1["bodies"][0].get_facecolor().flatten(), label='new')
patch2 = mpatches.Patch(color=parts2["bodies"][0].get_facecolor().flatten(), label='old')

line1 = mlines.Line2D([], [], color='grey', label='90% credible interval')
points1 = mlines.Line2D([], [], color='grey', marker='o',linestyle='None', label='median')
line3 = mlines.Line2D([], [], color='grey',ls='--', label='snr theory trend')

positions = np.log(duration_array)
medians1 = [np.median(x) for x in log10_new_likelihood_qfactor]

ax.scatter(positions, medians1, marker='o', color=parts1["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)

medians2 = [np.median(x) for x in log10_old_likelihood_qfactor]
ax.scatter(positions, medians2, marker='o', color=parts2["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)

ax.set_xlabel(r'$T/\tau$',fontsize = 18)
ax.set_ylabel(r'$\log_{10} \tau \Delta f$',fontsize = 18)
ax.set_xticks(np.log(duration_array))
ax.set_xticklabels([str(x/4) for x in duration_array],fontsize = 12)

plt.yticks(fontsize = 12)
plt.legend(handles=[patch1, patch2, line1, points1], loc=2,fontsize = 11)
plt.savefig('log_qfactor_violinplot_withouttrend_divided.pdf',dpi=300)
plt.show()
plt.close()
    
fig, ax = plt.subplots(figsize = (15,5),constrained_layout=True)
labels = []

parts1 = ax.violinplot(log10_new_likelihood_qfactor,positions=np.log(duration_array),showmedians=False,widths = 0.25,showextrema=False)
parts2 = ax.violinplot(log10_old_likelihood_qfactor,positions=np.log(duration_array),showmedians=False,widths = 0.25,showextrema=False)
for i, pos in enumerate(positions):
    lower1, upper1 = np.percentile(log10_new_likelihood_qfactor[i], quantile_values)
    lower2, upper2 = np.percentile(log10_old_likelihood_qfactor[i], quantile_values)
    ax.hlines([lower1, upper1], pos-0.25/2, pos, color='C0', lw=2)
    ax.hlines([lower2, upper2], pos, pos+0.25/2, color='C1', lw=2)
for pc in parts1['bodies']:
    for path in pc.get_paths():
        vertices = path.vertices
        vertices[:, 0] = np.clip(vertices[:, 0], -np.inf, vertices[:, 0].mean())
        
for pc in parts2['bodies']:
    for path in pc.get_paths():
        vertices = path.vertices
        vertices[:, 0] = np.clip(vertices[:, 0], vertices[:, 0].mean(),np.inf)
        
ax.set_xticks(np.log(duration_array))
ax.set_xticklabels([str(x) for x in duration_array],fontsize = 12)

patch1 = mpatches.Patch(color=parts1["bodies"][0].get_facecolor().flatten(), label='new')
patch2 = mpatches.Patch(color=parts2["bodies"][0].get_facecolor().flatten(), label='old')

line1 = mlines.Line2D([], [], color='grey', label='90% credible interval')
points1 = mlines.Line2D([], [], color='grey', marker='o',linestyle='None', label='median')

line3 = mlines.Line2D([], [], color='green',ls='--', label=r'$\tau \Delta f$ theory trend')

positions = np.log(duration_array)
medians1 = [np.median(x) for x in log10_new_likelihood_qfactor]

ax.scatter(positions, medians1, marker='o', color=parts1["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)

medians2 = [np.median(x) for x in log10_old_likelihood_qfactor]
ax.scatter(positions, medians2, marker='o', color=parts2["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)
ax.scatter(positions, medians2, marker='o', color=parts2["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)
ax.plot(positions,np.log10(qfactor_array),color = 'green',ls = '--',label = r'$\tau \Delta f$ theory trend')

ax.set_xlabel(r'$T/\tau$',fontsize = 18)
ax.set_ylabel(r'$\log_{10} \tau \Delta f$',fontsize = 18)
ax.set_xticks(np.log(duration_array))
ax.set_xticklabels([str(x/4) for x in duration_array],fontsize = 12)

plt.yticks(fontsize = 12)
plt.legend(handles=[patch1, patch2, line1, points1,line3], loc=2,fontsize = 11)


plt.savefig('log_qfactor_violinplot_divided.pdf',dpi=300)
plt.show()
plt.close()

# %% [markdown]
# ## logB violin plot

# %%
file_array_new = []
file_array_old = []
for time_duration in [1,2,3,4,8,12,24,52]:
    file=glob('*duration=%d_*HWP/*0.077*.csv'%time_duration)[0]
    file_array_new.append(file)
    file=glob('**duration=%d_*HWP/*0.077*.csv'%time_duration)[1]
    file_array_old.append(file)

# %%
file_array_new_noise = []
file_array_old_noise = []
for time_duration in [1,2,3,4,8,12,24,52]:
    file=glob('*duration=%d_4parameter_HWP/*0.000*.csv'%time_duration)[0]
    file_array_new_noise.append(file)
    file=glob('*duration=%d_4parameter_HWP/*0.000*.csv'%time_duration)[1]
    file_array_old_noise.append(file)

# %%
new_likelihood_logB_upper = []
new_likelihood_logB_lower = []
old_likelihood_logB_upper = []   
old_likelihood_logB_lower = []    
for file_new,file_old in zip(file_array_new_noise,file_array_old_noise):
	data = pd.read_csv(file_new)
	log_b = data["logB"]
	new_likelihood_logB_upper.append(np.percentile(log_b.values, 95))
	new_likelihood_logB_lower.append(np.percentile(log_b.values, 5))
	data = pd.read_csv(file_old)
	log_b = data["logB"]
	old_likelihood_logB_upper.append(np.percentile(log_b.values, 95))
	old_likelihood_logB_lower.append(np.percentile(log_b.values, 5))
new_likelihood_logB_upper = np.array(new_likelihood_logB_upper)
new_likelihood_logB_lower = np.array(new_likelihood_logB_lower)
old_likelihood_logB_upper = np.array(old_likelihood_logB_upper)
old_likelihood_logB_lower = np.array(old_likelihood_logB_lower)

# %%
# quantilesnew = [[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95]]
# quantilesold = [[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95]]

fig, ax = plt.subplots(figsize = (15,4),constrained_layout=True)
labels = []

new_likelihood_logB = []
old_likelihood_logB = []
for file_new,file_old in zip(file_array_new,file_array_old):
    data = pd.read_csv(file_new)
    log_b = data["logB"]
    new_likelihood_logB.append(log_b.values)
    data = pd.read_csv(file_old)
    log_b = data["logB"]
    old_likelihood_logB.append(log_b.values)
parts1 = ax.violinplot(new_likelihood_logB,positions=np.log(duration_array),showmedians=False,widths = 0.25,showextrema=False)
parts2 = ax.violinplot(old_likelihood_logB,positions=np.log(duration_array),showmedians=False,widths = 0.25,showextrema=False)
quantile_values = [5, 95]
positions = np.log(duration_array)
for i, pos in enumerate(positions):
    lower1, upper1 = np.percentile(new_likelihood_logB[i], quantile_values)
    lower2, upper2 = np.percentile(old_likelihood_logB[i], quantile_values)
    ax.hlines([lower1, upper1], pos-0.25/2, pos, color='C0', lw=2)
    ax.hlines([lower2, upper2], pos, pos+0.25/2, color='C1', lw=2)
for pc in parts1['bodies']:
    for path in pc.get_paths():
        vertices = path.vertices
        vertices[:, 0] = np.clip(vertices[:, 0], -np.inf, vertices[:, 0].mean())
for pc in parts2['bodies']:
    for path in pc.get_paths():
        vertices = path.vertices
        vertices[:, 0] = np.clip(vertices[:, 0], vertices[:, 0].mean(),np.inf)
        
ax.set_xticks(np.log(duration_array))
ax.set_xticklabels([str(x) for x in duration_array],fontsize = 12)
patch1 = mpatches.Patch(color=parts1["bodies"][0].get_facecolor().flatten(), label='new')
patch2 = mpatches.Patch(color=parts2["bodies"][0].get_facecolor().flatten(), label='old')
patch3 = mpatches.Patch(alpha=0.2, color='gray', label='noise level')
line1 = mlines.Line2D([], [], color='grey', label='90% credible interval')
points1 = mlines.Line2D([], [], color='grey', marker='o',linestyle='None', label='median')

positions = np.log(duration_array)
medians1 = [np.median(x) for x in new_likelihood_logB]

ax.scatter(positions, medians1, marker='o', color=parts1["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)

medians2 = [np.median(x) for x in old_likelihood_logB]
ax.scatter(positions, medians2, marker='o', color=parts2["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)

ax.fill_between(np.log(duration_array), new_likelihood_logB_upper, new_likelihood_logB_lower, alpha=0.2, color='gray')
ax.fill_between(np.log(duration_array), old_likelihood_logB_upper, old_likelihood_logB_lower, alpha=0.2, color='gray')
ax.set_xlabel(r'$T/\tau$',fontsize = 18)
ax.set_ylabel('logB',fontsize = 18)

ax.set_xticks(np.log(duration_array))
ax.set_xticklabels([str(x/4) for x in duration_array],fontsize = 12)

plt.yticks(fontsize = 12)
plt.legend(handles=[patch1, patch2, line1, points1,patch3], loc=2,fontsize = 11)
plt.savefig('logB_violin_plot_divided.pdf',dpi=300)
plt.show()
plt.close()

# %% [markdown]
# ### Fig 17 upper

# %%
# quantilesnew = [[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95]]
# quantilesold = [[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95],[0.05,0.95]]
fig, ax = plt.subplots(figsize = (15,4),constrained_layout=True)
labels = []

new_likelihood_logB = []
old_likelihood_logB = []
for file_new,file_old in zip(file_array_new_noise,file_array_old_noise):
    data = pd.read_csv(file_new)
    log_b = data["logB"]
    new_likelihood_logB.append(log_b.values)
    data = pd.read_csv(file_old)
    log_b = data["logB"]
    old_likelihood_logB.append(log_b.values)
parts1 = ax.violinplot(new_likelihood_logB,positions=np.log(duration_array),showmedians=False,widths = 0.25,showextrema=False)
parts2 = ax.violinplot(old_likelihood_logB,positions=np.log(duration_array),showmedians=False,widths = 0.25,showextrema=False)

quantile_values = [5, 95]
positions = np.log(duration_array)
for i, pos in enumerate(positions):
    lower1, upper1 = np.percentile(new_likelihood_logB[i], quantile_values)
    lower2, upper2 = np.percentile(old_likelihood_logB[i], quantile_values)
    ax.hlines([lower1, upper1], pos-0.25/2, pos, color='C0', lw=2)
    ax.hlines([lower2, upper2], pos, pos+0.25/2, color='C1', lw=2)
for pc in parts1['bodies']:
    for path in pc.get_paths():
        vertices = path.vertices
        vertices[:, 0] = np.clip(vertices[:, 0], -np.inf, vertices[:, 0].mean())
for pc in parts2['bodies']:
    for path in pc.get_paths():
        vertices = path.vertices
        vertices[:, 0] = np.clip(vertices[:, 0], vertices[:, 0].mean(),np.inf)
ax.set_xticks(np.log(duration_array))
ax.set_xticklabels([str(x) for x in duration_array],fontsize = 12)
patch1 = mpatches.Patch(color=parts1["bodies"][0].get_facecolor().flatten(), label='new')
patch2 = mpatches.Patch(color=parts2["bodies"][0].get_facecolor().flatten(), label='old')
patch3 = mpatches.Patch(alpha=0.2, color='gray', label='noise level')

line1 = mlines.Line2D([], [], color='grey', label='90% credible interval')
points1 = mlines.Line2D([], [], color='grey', marker='o',linestyle='None', label='median')

positions = np.log(duration_array)
medians1 = [np.median(x) for x in new_likelihood_logB]

ax.scatter(positions, medians1, marker='o', color=parts1["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)

medians2 = [np.median(x) for x in old_likelihood_logB]
ax.scatter(positions, medians2, marker='o', color=parts2["bodies"][0].get_facecolor().flatten(), s=60, zorder=3,alpha = 1)
ax.set_xlabel(r'$T/\tau$',fontsize = 18)
ax.set_ylabel('logB',fontsize = 18)

ax.set_xticks(np.log(duration_array))
ax.set_xticklabels([str(x/4) for x in duration_array],fontsize = 12)

plt.yticks(fontsize = 12)
plt.legend(handles=[patch1, patch2, line1, points1], loc=2,fontsize = 11)
plt.savefig('logB_violin_plot_noise_divided.pdf',dpi=300)
plt.show()
plt.close()

# %% [markdown]
# # logB distribution for different sampling parameters
# Fig 6

# %%
import pandas as pd
import scipy
import os
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats
import bilby
import corner

from glob import glob

# %%
file_index_qnm_new=['npoints=1000_duration=12_4parameter_HWP/4parameter_echoamplitude=0.077_newlikelihood_all.csv',
 'npoints=1000_qfactor=100_priorscaled_4parameter_HWP_new/4parameter_echoamplitude=0.077_newlikelihood_all.csv',
 'npoints=2000_qfactor=100_priorscaled_4parameter_HWP_new/4parameter_echoamplitude=0.077_newlikelihood_all.csv']

# %%
plt.figure(figsize=(8, 5))
file = file_index_qnm_new[0]
data = pd.read_csv(file)
amplitude = float(file[file.find('amplitude=')+len('amplitude='):file.find('_',file.find('amplitude='))])

log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-3.5, log_b.max() + 10, 200)
plt.plot(x, probDensityFun(x), "C0")
plt.axvline(np.mean(log_b), color="C0", linestyle=":")
plt.hist(log_b,12,density=1,alpha=0.3,label='(23, 1000)',)

file = file_index_qnm_new[1]
data = pd.read_csv(file)

log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-18, log_b.max() + 14, 200)
plt.plot(x, probDensityFun(x), "C2")
plt.axvline(np.mean(log_b), color="C2", linestyle=":")
plt.hist(log_b,14,density=1,color="C2",alpha=0.3,label='(100, 1000)',)

file = file_index_qnm_new[2]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-14, log_b.max() + 14, 200)
plt.plot(x, probDensityFun(x), "C3")
plt.axvline(np.mean(log_b), color="C3", linestyle=":")
plt.hist(log_b,10, density=1, color="C3",alpha=0.3,label='(100, 2000)')
plt.legend(loc=1, bbox_to_anchor=(1,0.9), fontsize = 14)
plt.text(85,0.03,r'($\tau_{inj}\Delta f_{inj},\, n_{liv}$)',fontsize=14)
plt.xlabel('log Bayes factor',fontsize = 15)
plt.tick_params(labelsize =14)
plt.xlim(-20,115)
plt.savefig('logB_HFnlive_signal.pdf',dpi=300)
plt.show()

# %%
file_index_qnm_new=['npoints=1000_qfactor=200_priorscaled_Tfactor100_4parameter_HWP_new/4parameter_echoamplitude=0.054_newlikelihood_all.csv',
 'npoints=2000_qfactor=200_priorscaled_Tfactor100_4parameter_HWP_new/4parameter_echoamplitude=0.054_newlikelihood_all.csv']

file_index_qnm_old =['npoints=1000_qfactor=200_priorscaled_Tfactor100_4parameter_HWP_new/4parameter_echoamplitude=0.054_oldlikelihood_all.csv',
 'npoints=2000_qfactor=200_priorscaled_Tfactor100_4parameter_HWP_new/4parameter_echoamplitude=0.054_oldlikelihood_all.csv']

# %%
plt.figure(figsize=(8, 5))
file = file_index_qnm_new[0]
data = pd.read_csv(file)
amplitude = float(file[file.find('amplitude=')+len('amplitude='):file.find('_',file.find('amplitude='))])
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-10, log_b.max() + 7, 200)
plt.plot(x, probDensityFun(x), "C0")
plt.axvline(np.mean(log_b), color="C0", linestyle=":")
plt.hist(log_b,12,density=1,alpha=0.3,label='new (100, 1000)',)

file = file_index_qnm_old[0]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-10, log_b.max() + 6, 200)
plt.plot(x, probDensityFun(x), "C1")
plt.axvline(np.mean(log_b), color="C1", linestyle=":")
plt.hist(log_b,12,density=1,alpha=0.3,label='old (100, 1000)',)


file = file_index_qnm_new[1]
data = pd.read_csv(file)
amplitude = float(file[file.find('amplitude=')+len('amplitude='):file.find('_',file.find('amplitude='))])
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-10, log_b.max() + 3, 200)
plt.plot(x, probDensityFun(x), "C2")
plt.axvline(np.mean(log_b), color="C2", linestyle=":")
plt.hist(log_b,12,density=1,color="C2",alpha=0.3,label='new (100, 2000)',)

file = file_index_qnm_old[1]
data = pd.read_csv(file)
log_b = data["logB"]
probDensityFun = scipy.stats.gaussian_kde(log_b)
x = np.linspace(-10, log_b.max() + 5, 200)
plt.plot(x, probDensityFun(x), "C3")
plt.axvline(np.mean(log_b), color="C3", linestyle=":")
plt.hist(log_b,11,density=1,color="C3", alpha=0.3,label='old (100, 2000)',)
plt.legend(loc=1, bbox_to_anchor=(1,0.9), fontsize = 14)
plt.text(45,0.055,'($T\Delta f_{inj},\, n_{liv}$)',fontsize=14)
plt.xlabel('log Bayes factor',fontsize = 15)
plt.tick_params(labelsize =14)
plt.xlim(-12,60)
plt.savefig('logB_LFnlive_signal.pdf',bbox_inches='tight',pad_inches=0.1)
plt.show()
